# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('indian_bus_fare_sample.csv')

# %%
df.head()

# %%
sns.countplot(df['Destination'])

# %%
df['Agency'].value_counts().plot(kind='pie',autopct='%.2f')

# %%
import matplotlib.pyplot as plt
plt.hist(df['Total Seats'],bins=5)

# %%
sns.distplot(df['Total Seats'])

# %%
sns.boxplot(df['Total Seats'])

# %%
df['Total Seats'].min()

# %%
df['Total Seats'].max()

# %%
df['Total Seats'].mean()

# %%
df['Total Seats'].skew()
